# %% [markdown]
# <a href="https://colab.research.google.com/github/DB11051998/ARIMA/blob/master/pectoral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Canny Edge Detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %matplotlib inline 
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage
import matplotlib.image as mpimg
import matplotlib.pylab as plt
from scipy.ndimage import affine_transform, zoom
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Viewer requires Qt
#   import sys

# %%
from skimage import io
from skimage import feature
from skimage import color
from matplotlib import pylab as pylab
img1 = io.imread("/content/drive/My Drive/Assessment_For_Finding_An_Intern/mammo_1.png")
img1 = color.rgb2gray(img1)
edge = feature.canny(img1,6)
fig, (axes1, axes2) = pylab.subplots(1, 2, figsize=(15, 10), sharex=True, sharey=True)
axes1.axis('off'), axes1.imshow(img1, cmap=pylab.cm.gray), axes1.set_title('Input image')
axes2.axis('off'), axes2.imshow(edge, cmap=pylab.cm.gray), axes2.set_title('Canny edge detection')
pylab.show()

# %%
from skimage import io
from skimage import feature
from skimage import color
from matplotlib import pylab as pylab
img2 = io.imread("/content/drive/My Drive/Assessment_For_Finding_An_Intern/mammo_2.png")
img2 = color.rgb2gray(img2)
edge = feature.canny(img2,6)
fig, (axes1, axes2) = pylab.subplots(1, 2, figsize=(15, 10), sharex=True, sharey=True)
axes1.axis('off'), axes1.imshow(img2, cmap=pylab.cm.gray), axes1.set_title('Input image')
axes2.axis('off'), axes2.imshow(edge, cmap=pylab.cm.gray), axes2.set_title('Canny edge detection')
pylab.show()

# %%
from skimage import io
from skimage import feature
from skimage import color
from matplotlib import pylab as pylab
img3 = io.imread("/content/drive/My Drive/Assessment_For_Finding_An_Intern/mammo_3.jpg")
img3 = color.rgb2gray(img3)
edge = feature.canny(img3,6)
fig, (axes1, axes2) = pylab.subplots(1, 2, figsize=(15, 10), sharex=True, sharey=True)
axes1.axis('off'), axes1.imshow(img3, cmap=pylab.cm.gray), axes1.set_title('Input image')
axes2.axis('off'), axes2.imshow(edge, cmap=pylab.cm.gray), axes2.set_title('Canny edge detection')
pylab.show()

# %%
from skimage import io
from skimage import feature
from skimage import color
from matplotlib import pylab as pylab
img4 = io.imread("/content/drive/My Drive/Assessment_For_Finding_An_Intern/mammo_4.jpg")
img4 = color.rgb2gray(img4)
edge = feature.canny(img4,6)
fig, (axes1, axes2) = pylab.subplots(1, 2, figsize=(15, 10), sharex=True, sharey=True)
axes1.axis('off'), axes1.imshow(img4, cmap=pylab.cm.gray), axes1.set_title('Input image')
axes2.axis('off'), axes2.imshow(edge, cmap=pylab.cm.gray), axes2.set_title('Canny edge detection')
pylab.show()

# %%
from skimage import io
from skimage import feature
from skimage import color
from matplotlib import pylab as pylab
img5 = io.imread("/content/drive/My Drive/Assessment_For_Finding_An_Intern/mammo_5.jpg")
img5 = color.rgb2gray(img5)
edge = feature.canny(img5,6)
fig, (axes1, axes2) = pylab.subplots(1, 2, figsize=(15, 10), sharex=True, sharey=True)
axes1.axis('off'), axes1.imshow(img5, cmap=pylab.cm.gray), axes1.set_title('Input image')
axes2.axis('off'), axes2.imshow(edge, cmap=pylab.cm.gray), axes2.set_title('Canny edge detection')
pylab.show()

# %% [markdown]
# Dear (to be) Intern, please note the following :
#
#
# > If we observe the output of <b>canny edge detection</b> on different mammograms the <font color='red'><b>pectoral muscle</b></font> separation is not happening that well.
#
# Certain modification with the help of <b>hough transform</b> _or any other suitable transformation technique_ is required. Hence further job is to code and apply most some transformation or generate a striaght line in some way to distinguish the pectoral muscle clearly.
#
# Post that a new image as to be generated, such that it should be without the pectoral muscle part. You can fill the pectoral muscle part with all black pixels, so that it is clearly distinguished.

# %%
##stored the path of the image in a list
path=[]
import os
for dirname, _, filenames in os.walk('/content/drive/My Drive/Assessment_For_Finding_An_Intern'):
    for filename in filenames:
      if 'mammo' in filename:
        path.append(os.path.join(dirname, filename))

# %%
# Code for applying transformation like Hough Transform 
# or some other transform
from skimage.transform import hough_line, hough_line_peaks
from skimage.filters import threshold_otsu
from skimage.transform import probabilistic_hough_line
from skimage import filters
from skimage import exposure
from scipy import ndimage as ndi
from skimage.filters.rank import enhance_contrast
from skimage.morphology import disk
from skimage.filters.rank import mean_bilateral
from skimage.filters import rank
from skimage.transform import (hough_line, hough_line_peaks,
                               probabilistic_hough_line)
from skimage.filters import unsharp_mask
from skimage.filters.rank import enhance_contrast_percentile
from skimage.draw import line




plt.figure(figsize=(10,10))

gamma_corrected = exposure.adjust_log(img5,3)
plt.plot(figsize=(15,15))
edge = feature.canny(gamma_corrected,6)

plt.imshow(edge,cmap='gray')

img=img5
# Classic straight-line Hough transform.
h, theta, d = hough_line(edge)

# Generating figure 1.
fig, (ax2) = plt.subplots(1, 1, figsize=(12, 6))
plt.tight_layout()


ax2.imshow(edge, cmap='gray')
row1, col1 = img.shape
for _, angle, dist in zip(*hough_line_peaks(h, theta, d)):
  if(angle<0):
    count=count+1
for _, angle, dist in zip(*hough_line_peaks(h, theta, d)):
    print(angle)
    if(dist>30 and dist<80  and angle>0 ):
      y0 = ((dist - 0 * np.cos(angle)) / np.sin(angle))
      y1 = ((dist - (col1 * np.cos(angle))) / np.sin(angle))


      a = np.cos(angle)
      b = np.sin(angle)

      ax2.plot((0, col1), (y0, y1), '-r')
      #m=-(y1-col1)/y0
    if(dist>30 and dist<40 and angle<0 and count>=10 ):
      y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
      y1 = (dist - col1 * np.cos(angle)) / np.sin(angle)
      ax2.plot((0, col1), (y0, y1), '-r') 
ax2.axis((0, col1, row1, 0))
ax2.set_title('Detected lines')
ax2.set_axis_off()
print(y1)
# Out:
# 0.008775398473714446
# 0.07897858626343046
# -1849.243661374704

# %%
x = np.linspace(0,col1)
y=np.linspace(abs(y0),abs(y1))
fig, ax = plt.subplots()
ax.fill(x, y, 'b', alpha=0.3)
plt.show()

# %%
#pectoral function is used to find the boundary line in the pectoral muscle

def pectoral(imgq,i):
  '''parameters:-
                imgq->'path of the image'
                i->serial no of image
   '''             
  img = io.imread(imgq)
  img = color.rgb2gray(img)
  gamma_corrected = exposure.adjust_log(img,3)
  fig,(ax,ax2) = plt.subplots(1,2, figsize=(12, 6))
  plt.tight_layout()
  edge = feature.canny(gamma_corrected,6)
  h, theta, d = hough_line(edge)
  count=0
  ax.imshow(edge, cmap='gray')
  ax2.imshow(img,cmap='gray')
  for _, angle, dist in zip(*hough_line_peaks(h, theta, d)):
    if(angle<0):
      count=count+1
  for _, angle, dist in zip(*hough_line_peaks(h, theta, d)):
    #print(angle)
    if(dist>30 and dist<80  and angle>0 ):
      y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
      y1 = (dist - col1 * np.cos(angle)) / np.sin(angle)
      ax.plot((0, col1), (y0, y1), '-r')
      ax2.plot((0, col1), (y0, y1), '-r')
    if(dist>30 and dist<40 and angle<0 and count>=10 ):
      y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
      y1 = (dist - col1 * np.cos(angle)) / np.sin(angle)
      ax.plot((0, col1), (y0, y1), '-r')
      #m=(y1-col1)/y0
      ax2.plot((0, col1), (y0, y1), '-r')

  ax.axis((0, col1, row1, 0))
  ax2.axis((0, col1, row1, 0))
  ax.set_title('Detected lines')
  ax.set_axis_off()

# %%
# Code to fill the pectoral muscle part with all black pixels, 
# so that it is clearly distinguished.

# %%
# Try the above 2 steps on all images from mammo_1 to mammo_5
# It should give clear visual results , where a layman can see that 
# the pectoral muscle part is filled black.
for i in range(len(path)):
  pectoral(path[i],i)

# %% [markdown]
# > **Please complete the above work and submit with-in deadline.** _Work submitted within deadlines would only be considered._
#
# > **Submit** your work to the shivajidpawar20@gmail.com and cc : to rocky@suvenconsultants.com
#
# > **Deadline** is specified in the LI posting / comment itself.
#
# > Wishing each one participating "All the best".
